# %% [markdown]
# # Hospital Info File Data Cleaning
#
# This notebook is used to clean the raw hospital info file, which was created initially by Julie Leung using Microsoft Excel.
#
# ### Information about the Source Data:
# * Geographic location data such as City Area, City Population and City Latitude and Longitude were provided by the Data > Geography feature described here:
#     * https://support.microsoft.com/en-us/office/get-geographic-location-data-287b4cf2-3d7d-4bc1-b412-3d00f45dbbd6
# * The Hospital addresses were manually looked up and filled in using Google Maps.
# * The delination for 'services' provided were informed by a manual look up of each hospital at Alberta Health Services' Find Healthcare website at:
#     * https://www.albertahealthservices.ca/findhealth/search.aspx?type=facility#icon_banner
# * The 'citytype' categorization ('peri', 'urban', rural') was made arbitrarily as follows:
#     * Population < 60,000:  classify as 'rural'
#     * Population > 60,000 and < 100,000:  classify as 'peri' (peri-urban)
#     * Population > 100,000:  classify as 'urban'
#
# ### What is done in this notebook:
# * The raw Hospital Info file is:
# * cleaned
# * Geocode API is queried to fill in hospital latitude and hospital logitude
# * Where Geocode API returns empty payload, hospital latitude and longitude values are looked up manually on geocoder.ca and filled into the dataframe
# * Finalized "cleaned" hospital info dataframe is saved as .csv

# %%
from modules.utility import Utility
import pandas as pd
import time

# %%
# Load Hospital Info
info = Utility.get_raw_hospital_info_dataframe()

# %%
info.head()
# Out:
#                           name   id   services     city province  city.area  \
# 0  Alberta Children's Hospital  ach  emergency  Calgary  Alberta        826
# 1     Foothills Medical Centre  fmc  emergency  Calgary  Alberta        826
# 2        Peter Lougheed Centre  plc  emergency  Calgary  Alberta        826
# 3   Rockyview General Hospital  rgh  emergency  Calgary  Alberta        826
# 4          South Health Campus  shc  emergency  Calgary  Alberta        826
#
#    city.lat  city.long   city.pop citytype  \
# 0     51.05  -114.0667  1,306,784    urban
# 1     51.05  -114.0667  1,306,784    urban
# 2     51.05  -114.0667  1,306,784    urban
# 3     51.05  -114.0667  1,306,784    urban
# 4     51.05  -114.0667  1,306,784    urban
#
#                                            address  hosp_lat  hosp_long
# 0       28 Oki Drive NW, Calgary, Alberta, T3B 6A8       NaN        NaN
# 1     1403 29 Street NW, Calgary, Alberta, T2N 2T9       NaN        NaN
# 2     3500 26 Avenue NE, Calgary, Alberta, T1Y 6J4       NaN        NaN
# 3     7007 14 Street SW, Calgary, Alberta, T2V 1P9       NaN        NaN
# 4  4448 Front Street SE, Calgary, Alberta, T3M 1M4       NaN        NaN

# %% [markdown]
# ### Get geocoded coordinates for all hospitals
#
# Note: "get_Geocode" function is defined in the Utility class

# %%
for address in info['address']:
    # Set mask
    mask = (info['address'] == address)

    print(f"\nWorking on hospital {info[mask]['id'].iloc[0]}, getting lat/long for address: {address}")

    # Call the API
    lat=0
    long=0
    lat,long = Utility.get_geocode(address)  # Remove comment when ready to run

    # Set the lat and long for this line in the info df
    print(f"     Writing lat={lat} and long={long} into the info dataframe...")
    info.loc[mask, 'hosp_lat'] = lat
    info.loc[mask, 'hosp_long'] = long

    # Sleep for 1 second, as geocode.maps.co has a call limit of 2 per second
    time.sleep(2)  # Remove comment when ready to run
# Out:
# Working on hospital ach, getting lat/long for address: 28 Oki Drive NW, Calgary, Alberta, T3B 6A8
#      Calling API: request_url = https://geocode.maps.co/search?q=28 Oki Drive NW, Calgary, Alberta, T3B 6A8
#      Writing lat=51.0747591 and long=-114.1468334 into the info dataframe...
#
# Working on hospital fmc, getting lat/long for address: 1403 29 Street NW, Calgary, Alberta, T2N 2T9
#      Calling API: request_url = https://geocode.maps.co/search?q=1403 29 Street NW, Calgary, Alberta, T2N 2T9
#           *** Inside get_geocode(): payload is empty!  Please check out address: 1403 29 Street NW, Calgary, Alberta, T2N 2T9!
#      Writing lat=0 and long=0 into the info dataframe...
#
# Working on hospital plc, getting lat/long for address: 3500 26 Avenue NE, Calgary, Alberta, T1Y 6J4
#      Calling API: request_url = https://geocode.maps.co/search?q=3500 26 Avenue NE, Calgary, Alberta, T1Y 6J4
#      Writing lat=51.0789144 and long=-113.9846106 into the info dataframe...
#
# Working on hospital rgh, getting lat/long for address: 7007 14 Street SW, Calgary, Alberta, T2V 1P9
#      Calling API: request_url = https://geocode.maps.co/search?q=7007 14 Street SW, Calgary, Alberta, T2V 1P9
#      Writing lat=50.9900558 and long=-114.09707702684253 into the info dataframe...
#
# Working on hospital shc, getting lat/long for address: 4448 Front Street SE, Calgary, Alberta, T3M 1M4
#      Calling API: request_url = https://geocode.maps.co/search?q=4448 Front Street SE, Calgary, Alberta, T3M 1M4
#           *** Inside get_geocode(): payload is empty!  Please check out address: 4448 Front Street SE, Calgary, Alberta, T3M 1M4!
#      Writing lat=0 and long=0 into the info dataframe...
#
# Working on hospital smcc, getting lat/long for address: 1213 4 Street SW, Calgary, Alberta, T2R 0X7
#      Calling API: request_url = https://geocode.maps.co/search?q=1213 4 Street SW, Calgary, Alberta, T2R 0X7
#      Writing lat=51.04116535 and long=-114.0721785791019 into the info dataframe...
#
# Working on hospital schc, getting lat/long for address: 31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5
#      Calling API: request_url = https://geocode.maps.co/search?q=31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5
#           *** Inside get_geocode(): payload is empty!  Please check out address: 31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5!
#      Writing lat=0 and long=0 into the info dataframe...
#
# Working on hospital achc, getting lat/long for address: 604 Main Street S, Airdrie, Alberta, T4B 3K7
#      Calling API: request_url = https://geocode.maps.co/search?q=604 Main Street S, Airdrie, Alberta, T4B 3K7
#      Writing lat=51.2871094 and long=-114.0134299 into the info dataframe...
#
# Working on hospital cchc, getting lat/long for address: 60 Grande Boulevard, Cochrane, Alberta, T4C 0S4
#      Calling API: request_url = https://geocode.maps.co/search?q=60 Grande Boulevard, Cochrane, Alberta, T4C 0S4
#      Writing lat=51.184675999999996 and long=-114.4738215 into the info dataframe...
#
# Working on hospital ohwc, getting lat/long for address: 11 Cimarron Common, Okotoks, Alberta, T1S 2E9
#      Calling API: request_url = https://geocode.maps.co/search?q=11 Cimarron Common, Okotoks, Alberta, T1S 2E9
#      Writing lat=50.707517800000005 and long=-113.9735785300802 into the info dataframe...
#
# Working on hospital dgh, getting lat/long for address: 101 Erie Street S, Devon, Alberta, T9G 1A6
#      Calling API: request_url = https://geocode.maps.co/search?q=101 Erie Street S, Devon, Alberta, T9G 1A6
#           *** Inside get_geocode(): payload is empty!  Please check out address: 101 Erie Street S, Devon, Alberta, T9G 1A6!
#      Writing lat=0 and long=0 into the info dataframe...
#
# Working on hospital gnch, getting lat/long for address: 1100 Youville Drive NW, Edmonton, Alberta, T6L 5X8
#      Calling API: request_url = https://geocode.maps.co/search?q=1100 Youville Drive NW, Edmonton, Alberta, T6L 5X8
#      Writing lat=53.46157845 and long=-113.42967363459326 into the info dataframe...
#
# Working on hospital mch, getting lat/long for address: 16940 87 Avenue, Edmonton, Alberta, T5R 4H5
#      Calling API: request_url = https://geocode.maps.co/search?q=16940 87 Avenue, Edmonton, Alberta, T5R 4H5
#      Writing lat=53.52123585 and long=-113.6122311980354 into the info dataframe...
#
# Working on hospital rah, getting lat/long for address: 10240 Kingsway NW, Edmonton, Alberta, T5H 3V9
#      Calling API: request_url = https://geocode.maps.co/search?q=10240 Kingsway NW, Edmonton, Alberta, T5H 3V9
#      Writing lat=53.55685685 and long=-113.49689563358508 into the info dataframe...
#
# Working on hospital schc, getting lat/long for address: 9000 Emerald Drive, Sherwood Park, Alberta, T8H 0J3
#      Calling API: request_url = https://geocode.maps.co/search?q=9000 Emerald Drive, Sherwood Park, Alberta, T8H 0J3
#      Writing lat=53.56816 and long=-113.27673252791878 into the info dataframe...
#
# Working on hospital uah, getting lat/long for address: 8440 112 Street NW, Edmonton, Alberta, T6G 2B7
#      Calling API: request_url = https://geocode.maps.co/search?q=8440 112 Street NW, Edmonton, Alberta, T6G 2B7
#      Writing lat=53.52065665 and long=-113.52103868571429 into the info dataframe...
#
# Working on hospital fsch, getting lat/long for address: 9401 86 Avenue, Fort Saskatchewan, Alberta, T8L 0C6
#      Calling API: request_url = https://geocode.maps.co/search?q=9401 86 Avenue, Fort Saskatchewan, Alberta, T8L 0C6
#           *** Inside get_geocode(): payload is empty!  Please check out address: 9401 86 Avenue, Fort Saskatchewan, Alberta, T8L 0C6!
#      Writing lat=0 and long=0 into the info dataframe...
#
# Working on hospital lch, getting lat/long for address: 4210 48 Street, Leduc, Alberta, T9E 5Z3
#      Calling API: request_url = https://geocode.maps.co/search?q=4210 48 Street, Leduc, Alberta, T9E 5Z3
#      Writing lat=53.25512965 and long=-113.54603618108558 into the info dataframe...
#
# Working on hospital nchc, getting lat/long for address: 14007 50 Street NW, Edmonton, Alberta, T5A 5E4
#      Calling API: request_url = https://geocode.maps.co/search?q=14007 50 Street NW, Edmonton, Alberta, T5A 5E4
#           *** Inside get_geocode(): payload is empty!  Please check out address: 14007 50 Street NW, Edmonton, Alberta, T5A 5E4!
#      Writing lat=0 and long=0 into the info dataframe...
#
# Working on hospital stollery, getting lat/long for address: 8440 112 Street, Edmonton, Alberta, T6G 2B7
#      Calling API: request_url = https://geocode.maps.co/search?q=8440 112 Street, Edmonton, Alberta, T6G 2B7
#      Writing lat=53.52065665 and long=-113.52103868571429 into the info dataframe...
#
# Working on hospital sch, getting lat/long for address: 201 Boudreau Road, St. Albert, Alberta, T8N 6C4
#      Calling API: request_url = https://geocode.maps.co/search?q=201 Boudreau Road, St. Albert, Alberta, T8N 6C4
#      Writing lat=53.655272 and long=-113.62588844110243 into the info dataframe...
#
# Working on hospital whc, getting lat/long for address: 4405 South Park Drive, Stony Plain, Alberta, T7Z 2M7
#      Calling API: request_url = https://geocode.maps.co/search?q=4405 South Park Drive, Stony Plain, Alberta, T7Z 2M7
#           *** Inside get_geocode(): payload is empty!  Please check out address: 4405 South Park Drive, Stony Plain, Alberta, T7Z 2M7!
#      Writing lat=0 and long=0 into the info dataframe...
#
# Working on hospital crh, getting lat/long for address: 960 19 Street S, Lethbridge, Alberta, T1J 1W5
#      Calling API: request_url = https://geocode.maps.co/search?q=960 19 Street S, Lethbridge, Alberta, T1J 1W5
#      Writing lat=49.68522055 and long=-112.81620870069048 into the info dataframe...
#
# Working on hospital mhrh, getting lat/long for address: 666 5 Street SW, Medicine Hat, Alberta, T1A 4H6
#      Calling API: request_url = https://geocode.maps.co/search?q=666 5 Street SW, Medicine Hat, Alberta, T1A 4H6
#      Writing lat=50.03515935 and long=-110.70323827271375 into the info dataframe...
#
# Working on hospital rdrh, getting lat/long for address: 3942 50A Avenue, Red Deer, Alberta, T4N 4E7
#      Calling API: request_url = https://geocode.maps.co/search?q=3942 50A Avenue, Red Deer, Alberta, T4N 4E7
#      Writing lat=52.2606267 and long=-113.81838681692109 into the info dataframe...
#
# Working on hospital lhcc, getting lat/long for address: 5430 47 Avenue, Lacombe, Alberta, T4L 1G8
#      Calling API: request_url = https://geocode.maps.co/search?q=5430 47 Avenue, Lacombe, Alberta, T4L 1G8
#      Writing lat=52.46141725 and long=-113.74056718851031 into the info dataframe...
#
# Working on hospital ihc, getting lat/long for address: 5023 42 Street, Innisfail, Alberta, T4G 1A9
#      Calling API: request_url = https://geocode.maps.co/search?q=5023 42 Street, Innisfail, Alberta, T4G 1A9
#           *** Inside get_geocode(): payload is empty!  Please check out address: 5023 42 Street, Innisfail, Alberta, T4G 1A9!
#      Writing lat=0 and long=0 into the info dataframe...

# %% [markdown]
# # Dealing with addresses which had no geocode information returned
#
# The geocode API does not have latitude and longitude for all addresses (we'll forgive them, as it's a free service!)
#
# Therefore, "get_geocode" function is set to return (0,0) is there is no payload.  Next, we need to fill the lat/long of some hospitals manually.  Find out which ones those are.

# %%
# Figure out which hospitals we need to pull and fill manually
info[(info['hosp_lat']==0) | (info['hosp_long']==0)]
# Out:
#                                  name    id    services                  city  \
# 1            Foothills Medical Centre   fmc   emergency               Calgary
# 4                 South Health Campus   shc   emergency               Calgary
# 6         South Calgary Health Centre  schc  urgentcare               Calgary
# 10             Devon General Hospital   dgh   emergency        Devon, Alberta
# 16       Fort Sask Community Hospital  fsch   emergency     Fort Saskatchewan
# 18  Northeast Community Health Centre  nchc   emergency              Edmonton
# 21             WestView Health Centre   whc   emergency  Stony Plain, Alberta
# 26            Innisfail Health Centre   ihc   emergency    Innisfail, Alberta
#
#    province  city.area  city.lat  city.long   city.pop citytype  \
# 1   Alberta        826   51.0500  -114.0667  1,306,784    urban
# 4   Alberta        826   51.0500  -114.0667  1,306,784    urban
# 6   Alberta        826   51.0500  -114.0667  1,306,784    urban
# 10  Alberta         14   53.3633  -113.7322      6,545    rural
# 16  Alberta         48   53.7128  -113.2131     27,088    rural
# 18  Alberta        768   53.5333  -113.5000  1,010,899    urban
# 21  Alberta         36   53.5300  -114.0060     17,993    rural
# 26  Alberta         19   52.0333  -113.9500      7,985    rural
#
#                                               address hosp_lat hosp_long
# 1        1403 29 Street NW, Calgary, Alberta, T2N 2T9        0         0
# 4     4448 Front Street SE, Calgary, Alberta, T3M 1M4        0         0
# 6      31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5        0         0
# 10         101 Erie Street S, Devon, Alberta, T9G 1A6        0         0
# 16  9401 86 Avenue, Fort Saskatchewan, Alberta, T8...        0         0
# 18     14007 50 Street NW, Edmonton, Alberta, T5A 5E4        0         0
# 21  4405 South Park Drive, Stony Plain, Alberta, T...        0         0
# 26        5023 42 Street, Innisfail, Alberta, T4G 1A9        0         0

# %% [markdown]
# # Here are the results of manually getting data from geocoder.ca:
#
# * 1403 29 Street NW, Calgary, Alberta, T2N 2T9
#
# 51.064657, -114.130926
#
# * 4448 Front Street SE, Calgary, Alberta, T3M 1M4
#
# 50.880825, -113.952720
#
# * 31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5
#
# 50.902701, -114.058634
#
# * 101 Erie Street S, Devon, Alberta, T9G 1A6
#
# 53.352265, -113.728288
#
# * 9401 86 Avenue, Fort Saskatchewan, Alberta, T8L 0C6
#
# 53.693175, -113.213436
#
# * 14007 50 Street NW, Edmonton, Alberta, T5A 5E4
#
# 53.604308, -113.417595
#
# * 4405 South Park Drive, Stony Plain, Alberta, T7Z 2M7
#
# 53.538406, -113.978897
#
# * 5023 42 Street, Innisfail, Alberta, T4G 1A9
#
# 52.020008, -113.951336

# %%
# Writing the lat and longs to each address:

manual_geocodes = [
{
    'address':'1403 29 Street NW, Calgary, Alberta, T2N 2T9',
    'lat':51.064657,
    'long':-114.130926
}
,
{
    'address':'4448 Front Street SE, Calgary, Alberta, T3M 1M4',
    'lat':50.880825,
    'long':-113.952720
}
,
{
    'address':'31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5',
    'lat':50.902701,
    'long':-114.058634
}
,
{
    'address':'101 Erie Street S, Devon, Alberta, T9G 1A6',
    'lat':53.352265,
    'long':-113.728288
}
,
{
    'address':'9401 86 Avenue, Fort Saskatchewan, Alberta, T8L 0C6',
    'lat':53.693175,
    'long':-113.213436
}
,
{
    'address':'14007 50 Street NW, Edmonton, Alberta, T5A 5E4',
    'lat':53.604308,
    'long':-113.417595
}
,
{
    'address':'4405 South Park Drive, Stony Plain, Alberta, T7Z 2M7',
    'lat':53.538406,
    'long':-113.978897
}
,
{
    'address':'5023 42 Street, Innisfail, Alberta, T4G 1A9',
    'lat':52.020008,
    'long':-113.951336
}
]

for item in manual_geocodes:
    mask = info['address']==item['address']
    info.loc[mask, 'hosp_lat'] = item['lat']
    info.loc[mask, 'hosp_long'] = item['long']

# %%
info
# Out:
#                                   name        id    services  \
# 0          Alberta Children's Hospital       ach   emergency
# 1             Foothills Medical Centre       fmc   emergency
# 2                Peter Lougheed Centre       plc   emergency
# 3           Rockyview General Hospital       rgh   emergency
# 4                  South Health Campus       shc   emergency
# 5             Sheldon M. Chumir Centre      smcc  urgentcare
# 6          South Calgary Health Centre      schc  urgentcare
# 7      Airdrie Community Health Centre      achc  urgentcare
# 8     Cochrane Community Health Centre      cchc  urgentcare
# 9   Okotoks Health and Wellness Centre      ohwc  urgentcare
# 10              Devon General Hospital       dgh   emergency
# 11        Grey Nuns Community Hospital      gnch   emergency
# 12     Misericordia Community Hospital       mch   emergency
# 13            Royal Alexandra Hospital       rah   emergency
# 14       Strathcona Community Hospital      schc   emergency
# 15      University of Alberta Hospital       uah   emergency
# 16        Fort Sask Community Hospital      fsch   emergency
# 17            Leduc Community Hospital       lch   emergency
# 18   Northeast Community Health Centre      nchc   emergency
# 19        Stollery Children's Hospital  stollery   emergency
# 20         Sturgeon Community Hospital       sch   emergency
# 21              WestView Health Centre       whc   emergency
# 22           Chinook Regional Hospital       crh   emergency
# 23      Medicine Hat Regional Hospital      mhrh   emergency
# 24          Red Deer Regional Hospital      rdrh   emergency
# 25    Lacombe Hospital and Care Centre      lhcc   emergency
# 26             Innisfail Health Centre       ihc   emergency
#
#                     city province  city.area  city.lat  city.long   city.pop  \
# 0                Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 1                Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 2                Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 3                Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 4                Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 5                Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 6                Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 7       Airdrie, Alberta  Alberta         33   51.2917  -114.0140     74,100
# 8      Cochrane, Alberta  Alberta         30   51.1890  -114.4670     32,199
# 9                Okotoks  Alberta         20   50.7250  -113.9750     30,405
# 10        Devon, Alberta  Alberta         14   53.3633  -113.7322      6,545
# 11              Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 12              Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 13              Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 14         Sherwood Park  Alberta         71   53.5233  -113.3089     68,782
# 15              Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 16     Fort Saskatchewan  Alberta         48   53.7128  -113.2131     27,088
# 17        Leduc, Alberta  Alberta         42   53.2594  -113.5490     34,094
# 18              Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 19              Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 20   St. Albert, Alberta  Alberta         48   53.6303  -113.6258     68,232
# 21  Stony Plain, Alberta  Alberta         36   53.5300  -114.0060     17,993
# 22            Lethbridge  Alberta        122   49.6942  -112.8328     98,406
# 23          Medicine Hat  Alberta        112   50.0333  -110.6667     63,271
# 24     Red Deer, Alberta  Alberta        105   52.2681  -113.8111    100,844
# 25      Lacombe, Alberta  Alberta         21   52.4683  -113.7370     13,396
# 26    Innisfail, Alberta  Alberta         19   52.0333  -113.9500      7,985
#
#    citytype                                            address  \
# 0     urban         28 Oki Drive NW, Calgary, Alberta, T3B 6A8
# 1     urban       1403 29 Street NW, Calgary, Alberta, T2N 2T9
# 2     urban       3500 26 Avenue NE, Calgary, Alberta, T1Y 6J4
# 3     urban       7007 14 Street SW, Calgary, Alberta, T2V 1P9
# 4     urban    4448 Front Street SE, Calgary, Alberta, T3M 1M4
# 5     urban        1213 4 Street SW, Calgary, Alberta, T2R 0X7
# 6     urban     31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5
# 7      peri       604 Main Street S, Airdrie, Alberta, T4B 3K7
# 8      peri    60 Grande Boulevard, Cochrane, Alberta, T4C 0S4
# 9      peri      11 Cimarron Common, Okotoks, Alberta, T1S 2E9
# 10    rural         101 Erie Street S, Devon, Alberta, T9G 1A6
# 11    urban  1100 Youville Drive NW, Edmonton, Alberta, T6L...
# 12    urban        16940 87 Avenue, Edmonton, Alberta, T5R 4H5
# 13    urban      10240 Kingsway NW, Edmonton, Alberta, T5H 3V9
# 14     peri  9000 Emerald Drive, Sherwood Park, Alberta, T8...
# 15    urban     8440 112 Street NW, Edmonton, Alberta, T6G 2B7
# 16    rural  9401 86 Avenue, Fort Saskatchewan, Alberta, T8...
# 17     peri            4210 48 Street, Leduc, Alberta, T9E 5Z3
# 18    urban     14007 50 Street NW, Edmonton, Alberta, T5A 5E4
# 19    urban        8440 112 Street, Edmonton, Alberta, T6G 2B7
# 20     peri    201 Boudreau Road, St. Albert, Alberta, T8N 6C4
# 21    rural  4405 South Park Drive, Stony Plain, Alberta, T...
# 22     peri      960 19 Street S, Lethbridge, Alberta, T1J 1W5
# 23     peri    666 5 Street SW, Medicine Hat, Alberta, T1A 4H6
# 24    urban        3942 50A Avenue, Red Deer, Alberta, T4N 4E7
# 25    rural          5430 47 Avenue, Lacombe, Alberta, T4L 1G8
# 26    rural        5023 42 Street, Innisfail, Alberta, T4G 1A9
#
#               hosp_lat            hosp_long
# 0           51.0747591         -114.1468334
# 1            51.064657          -114.130926
# 2           51.0789144         -113.9846106
# 3           50.9900558  -114.09707702684253
# 4            50.880825           -113.95272
# 5          51.04116535   -114.0721785791019
# 6            50.902701          -114.058634
# 7           51.2871094         -114.0134299
# 8   51.184675999999996         -114.4738215
# 9   50.707517800000005   -113.9735785300802
# 10           53.352265          -113.728288
# 11         53.46157845  -113.42967363459326
# 12         53.52123585   -113.6122311980354
# 13         53.55685685  -113.49689563358508
# 14            53.56816  -113.27673252791878
# 15         53.52065665  -113.52103868571429
# 16           53.693175          -113.213436
# 17         53.25512965  -113.54603618108558
# 18           53.604308          -113.417595
# 19         53.52065665  -113.52103868571429
# 20           53.655272  -113.62588844110243
# 21           53.538406          -113.978897
# 22         49.68522055  -112.81620870069048
# 23         50.03515935  -110.70323827271375
# 24          52.2606267  -113.81838681692109
# 25         52.46141725  -113.74056718851031
# 26           52.020008          -113.951336

# %% [markdown]
# # Clean up / standardize the formatting of the 'city' column that came from Microsoft's service in the original Excel file

# %%
# Clean up the 'city' column that came from Excel
info['city'] = info['city'].str.replace(', Alberta', '')

# %%
info
# Out:
#                                   name        id    services  \
# 0          Alberta Children's Hospital       ach   emergency
# 1             Foothills Medical Centre       fmc   emergency
# 2                Peter Lougheed Centre       plc   emergency
# 3           Rockyview General Hospital       rgh   emergency
# 4                  South Health Campus       shc   emergency
# 5             Sheldon M. Chumir Centre      smcc  urgentcare
# 6          South Calgary Health Centre      schc  urgentcare
# 7      Airdrie Community Health Centre      achc  urgentcare
# 8     Cochrane Community Health Centre      cchc  urgentcare
# 9   Okotoks Health and Wellness Centre      ohwc  urgentcare
# 10              Devon General Hospital       dgh   emergency
# 11        Grey Nuns Community Hospital      gnch   emergency
# 12     Misericordia Community Hospital       mch   emergency
# 13            Royal Alexandra Hospital       rah   emergency
# 14       Strathcona Community Hospital      schc   emergency
# 15      University of Alberta Hospital       uah   emergency
# 16        Fort Sask Community Hospital      fsch   emergency
# 17            Leduc Community Hospital       lch   emergency
# 18   Northeast Community Health Centre      nchc   emergency
# 19        Stollery Children's Hospital  stollery   emergency
# 20         Sturgeon Community Hospital       sch   emergency
# 21              WestView Health Centre       whc   emergency
# 22           Chinook Regional Hospital       crh   emergency
# 23      Medicine Hat Regional Hospital      mhrh   emergency
# 24          Red Deer Regional Hospital      rdrh   emergency
# 25    Lacombe Hospital and Care Centre      lhcc   emergency
# 26             Innisfail Health Centre       ihc   emergency
#
#                  city province  city.area  city.lat  city.long   city.pop  \
# 0             Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 1             Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 2             Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 3             Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 4             Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 5             Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 6             Calgary  Alberta        826   51.0500  -114.0667  1,306,784
# 7             Airdrie  Alberta         33   51.2917  -114.0140     74,100
# 8            Cochrane  Alberta         30   51.1890  -114.4670     32,199
# 9             Okotoks  Alberta         20   50.7250  -113.9750     30,405
# 10              Devon  Alberta         14   53.3633  -113.7322      6,545
# 11           Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 12           Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 13           Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 14      Sherwood Park  Alberta         71   53.5233  -113.3089     68,782
# 15           Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 16  Fort Saskatchewan  Alberta         48   53.7128  -113.2131     27,088
# 17              Leduc  Alberta         42   53.2594  -113.5490     34,094
# 18           Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 19           Edmonton  Alberta        768   53.5333  -113.5000  1,010,899
# 20         St. Albert  Alberta         48   53.6303  -113.6258     68,232
# 21        Stony Plain  Alberta         36   53.5300  -114.0060     17,993
# 22         Lethbridge  Alberta        122   49.6942  -112.8328     98,406
# 23       Medicine Hat  Alberta        112   50.0333  -110.6667     63,271
# 24           Red Deer  Alberta        105   52.2681  -113.8111    100,844
# 25            Lacombe  Alberta         21   52.4683  -113.7370     13,396
# 26          Innisfail  Alberta         19   52.0333  -113.9500      7,985
#
#    citytype                                            address  \
# 0     urban         28 Oki Drive NW, Calgary, Alberta, T3B 6A8
# 1     urban       1403 29 Street NW, Calgary, Alberta, T2N 2T9
# 2     urban       3500 26 Avenue NE, Calgary, Alberta, T1Y 6J4
# 3     urban       7007 14 Street SW, Calgary, Alberta, T2V 1P9
# 4     urban    4448 Front Street SE, Calgary, Alberta, T3M 1M4
# 5     urban        1213 4 Street SW, Calgary, Alberta, T2R 0X7
# 6     urban     31 Sunpark Plaza SE, Calgary, Alberta, T2X 3W5
# 7      peri       604 Main Street S, Airdrie, Alberta, T4B 3K7
# 8      peri    60 Grande Boulevard, Cochrane, Alberta, T4C 0S4
# 9      peri      11 Cimarron Common, Okotoks, Alberta, T1S 2E9
# 10    rural         101 Erie Street S, Devon, Alberta, T9G 1A6
# 11    urban  1100 Youville Drive NW, Edmonton, Alberta, T6L...
# 12    urban        16940 87 Avenue, Edmonton, Alberta, T5R 4H5
# 13    urban      10240 Kingsway NW, Edmonton, Alberta, T5H 3V9
# 14     peri  9000 Emerald Drive, Sherwood Park, Alberta, T8...
# 15    urban     8440 112 Street NW, Edmonton, Alberta, T6G 2B7
# 16    rural  9401 86 Avenue, Fort Saskatchewan, Alberta, T8...
# 17     peri            4210 48 Street, Leduc, Alberta, T9E 5Z3
# 18    urban     14007 50 Street NW, Edmonton, Alberta, T5A 5E4
# 19    urban        8440 112 Street, Edmonton, Alberta, T6G 2B7
# 20     peri    201 Boudreau Road, St. Albert, Alberta, T8N 6C4
# 21    rural  4405 South Park Drive, Stony Plain, Alberta, T...
# 22     peri      960 19 Street S, Lethbridge, Alberta, T1J 1W5
# 23     peri    666 5 Street SW, Medicine Hat, Alberta, T1A 4H6
# 24    urban        3942 50A Avenue, Red Deer, Alberta, T4N 4E7
# 25    rural          5430 47 Avenue, Lacombe, Alberta, T4L 1G8
# 26    rural        5023 42 Street, Innisfail, Alberta, T4G 1A9
#
#               hosp_lat            hosp_long
# 0           51.0747591         -114.1468334
# 1            51.064657          -114.130926
# 2           51.0789144         -113.9846106
# 3           50.9900558  -114.09707702684253
# 4            50.880825           -113.95272
# 5          51.04116535   -114.0721785791019
# 6            50.902701          -114.058634
# 7           51.2871094         -114.0134299
# 8   51.184675999999996         -114.4738215
# 9   50.707517800000005   -113.9735785300802
# 10           53.352265          -113.728288
# 11         53.46157845  -113.42967363459326
# 12         53.52123585   -113.6122311980354
# 13         53.55685685  -113.49689563358508
# 14            53.56816  -113.27673252791878
# 15         53.52065665  -113.52103868571429
# 16           53.693175          -113.213436
# 17         53.25512965  -113.54603618108558
# 18           53.604308          -113.417595
# 19         53.52065665  -113.52103868571429
# 20           53.655272  -113.62588844110243
# 21           53.538406          -113.978897
# 22         49.68522055  -112.81620870069048
# 23         50.03515935  -110.70323827271375
# 24          52.2606267  -113.81838681692109
# 25         52.46141725  -113.74056718851031
# 26           52.020008          -113.951336

# %%
# Make lat/long into floats
info['hosp_lat'] = info['hosp_lat'].astype(float)
info['hosp_long'] = info['hosp_long'].astype(float)

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       27 non-null     object
#  1   id         27 non-null     object
#  2   services   27 non-null     object
#  3   city       27 non-null     object
#  4   province   27 non-null     object
#  5   city.area  27 non-null     int64
#  6   city.lat   27 non-null     float64
#  7   city.long  27 non-null     float64
#  8   city.pop   27 non-null     object
#  9   citytype   27 non-null     object
#  10  address    27 non-null     object
#  11  hosp_lat   27 non-null     float64
#  12  hosp_long  27 non-null     float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 2.9+ KB

# %% [markdown]
# # Write the cleaned hospital info .csv file to the appropriate subdirectory

# %%
# Write info out to cleandata subdirectory
info.to_csv(Utility.CLEAN_INFO_FILENAME, index=False)
