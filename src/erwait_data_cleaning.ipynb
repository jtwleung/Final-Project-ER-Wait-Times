# %% [markdown]
# # ER Wait Time File Data Cleaning
#
# This notebook is used to clean the raw ER wait time dataset.
#
# ### Information about the raw ER Wait Time dataset and Source of the Data:
# * The raw ER wait time dataset being handled within this notebook and used throughout the project **is the property of the Canadian Broadcasting Corporation (CBC)**.
#     * Alberta Health Services is the primary source of the data, and CBC is the aggregator of the data.
#     * The instantaneous wait times for each hospital in Alberta is at the follow Alberta Health Services website:  https://www.albertahealthservices.ca/waittimes/Page14230.aspx
#     * CBC has aggregated the AHS data by recording the instantaneous wait time one per hour for all available hospitals from the AHS website.
#     * The CBC reports on trends at each major city's ERs over the past 4 weeks here:
#         * Calgary:  https://www.cbc.ca/news/canada/calgary/calgary-er-wait-time-tracker-cbc-1.6701714
#         * Edmonton:  https://www.cbc.ca/news/canada/edmonton/edmonton-er-wait-time-tracker-cbc-1.6708480
#     * The raw data being handled here and in this project is the full dataset underlying the news reports above, and has been provided courtesy of the CBC for the purposes of this data science bootcamp project.
#         * As agreed with the CBC, the raw dataset will **not** be made available publically and **therefore this GitHub site does not include the raw .csv file in the `data` directory.**
# * CBC's Journalistic Standards and Practises can be found here.  Expand the `Data Journalism` dropdown for pertinent information.
#     * https://cbc.radio-canada.ca/en/vision/governance/journalistic-standards-and-practices/sources
#
#
# ### What is done in this notebook:
# The raw ER data file provided by the CBC:
# * is formatted for Python `datetime` objects
# * is "melted" so that Hospital becomes a column
# * is cleaned (null values dropped)
# * is merged with my Hospitals Info dataframe to provide additional features ('city', 'services', 'citytype') for models to train on
# * has feature engineering done to add a 'dayperiod', and separate the 'datetime' into 'weekofyear' and 'dayofweek' and 'hour'

# %%
from modules.utility import Utility
from IPython.display import display
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# # Uncomment code as required to force reload utility.py
# # Was only required during development of this notebook

# from importlib import reload
# import modules.utility
# reload(modules.utility)
# from modules.utility import Utility

# %% [markdown]
# # Setup

# %% [markdown]
# Remove display limits for column and row lengths, for easier viewing of dataframes

# %%
# Set no limits for number of columns and rows to display
# Utility.reset_display_max_cols_rows() to reset
Utility.setup_display_max_cols_rows()

# %% [markdown]
# Load the raw wait data

# %%
raw = Utility.get_raw_waittimes_dataframe()

# %% [markdown]
# Load Cleaned Hospital Info data to do joins to hospital wait time data later

# %%
info = Utility.get_hospital_info_dataframe()

# %% [markdown]
# # Create 'raw' df
# * Load in the .csv version of CBC's screen-scraped data with no changes in Excel

# %%
raw.head()
# Out:
#      Date  Year     Time  Alberta Children's Hospital  \
# 0  24-Sep  2022  6:22 PM                        201.0
# 1  24-Sep  2022  6:23 PM                        201.0
# 2  24-Sep  2022  8:25 PM                        236.0
# 3  24-Sep  2022  8:27 PM                        236.0
# 4  24-Sep  2022  8:28 PM                        237.0
#
#    Foothills Medical Centre  Peter Lougheed Centre  \
# 0                     188.0                  116.0
# 1                     188.0                  116.0
# 2                     140.0                  124.0
# 3                     140.0                  124.0
# 4                     140.0                  124.0
#
#    Rockyview General Hospital  South Health Campus  Sheldon M. Chumir Centre  \
# 0                       148.0                154.0                      89.0
# 1                       148.0                154.0                      89.0
# 2                       120.0                150.0                      58.0
# 3                       120.0                150.0                      58.0
# 4                       106.0                151.0                      58.0
#
#    South Calgary Health Centre  Airdrie Community Health Centre  \
# 0                        193.0                              NaN
# 1                        193.0                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
#
#    Cochrane Community Health Centre  Okotoks Health and Wellness Centre  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    Devon General Hospital  Grey Nuns Community Hospital  \
# 0                   132.0                         147.0
# 1                   132.0                         147.0
# 2                   158.0                         224.0
# 3                   158.0                         224.0
# 4                   158.0                         216.0
#
#    Misericordia Community Hospital  Royal Alexandra Hospital  \
# 0                            384.0                     287.0
# 1                            384.0                     287.0
# 2                            285.0                     415.0
# 3                            285.0                     415.0
# 4                            281.0                     415.0
#
#    Strathcona Community Hospital  University of Alberta Hospital  \
# 0                          196.0                           234.0
# 1                          196.0                           234.0
# 2                          251.0                           301.0
# 3                          251.0                           301.0
# 4                          251.0                           301.0
#
#    Fort Sask Community Hospital  Leduc Community Hospital  \
# 0                         295.0                     293.0
# 1                         295.0                     293.0
# 2                         188.0                     158.0
# 3                         188.0                     158.0
# 4                         188.0                     158.0
#
#    Northeast Community Health Centre  Stollery Children's Hospital  \
# 0                              135.0                         199.0
# 1                              135.0                         199.0
# 2                              283.0                         179.0
# 3                              283.0                         179.0
# 4                              283.0                         179.0
#
#    Sturgeon Community Hospital  WestView Health Centre  \
# 0                        261.0                   189.0
# 1                        261.0                   189.0
# 2                        203.0                   351.0
# 3                        203.0                   351.0
# 4                        203.0                   351.0
#
#    Chinook Regional Hospital  Medicine Hat Regional Hospital  \
# 0                       69.0                            96.0
# 1                       69.0                            96.0
# 2                       79.0                            60.0
# 3                       79.0                            60.0
# 4                       73.0                            60.0
#
#    Red Deer Regional Hospital  Lacombe Hospital and Care Centre  \
# 0                       161.0                               NaN
# 1                       161.0                               NaN
# 2                       241.0                               NaN
# 3                       241.0                               NaN
# 4                       230.0                               NaN
#
#    Innisfail Health Centre
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9186 entries, 0 to 9185
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                9186 non-null   object
#  1   Year                                9186 non-null   int64
#  2   Time                                9186 non-null   object
#  3   Alberta Children's Hospital         9111 non-null   float64
#  4   Foothills Medical Centre            9093 non-null   float64
#  5   Peter Lougheed Centre               9103 non-null   float64
#  6   Rockyview General Hospital          9108 non-null   float64
#  7   South Health Campus                 9108 non-null   float64
#  8   Sheldon M. Chumir Centre            9111 non-null   float64
#  9   South Calgary Health Centre         4556 non-null   float64
#  10  Airdrie Community Health Centre     5153 non-null   float64
#  11  Cochrane Community Health Centre    405 non-null    float64
#  12  Okotoks Health and Wellness Centre  0 non-null      float64
#  13  Devon General Hospital              9139 non-null   float64
#  14  Grey Nuns Community Hospital        9138 non-null   float64
#  15  Misericordia Community Hospital     9131 non-null   float64
#  16  Royal Alexandra Hospital            9138 non-null   float64
#  17  Strathcona Community Hospital       9139 non-null   float64
#  18  University of Alberta Hospital      9138 non-null   float64
#  19  Fort Sask Community Hospital        9138 non-null   float64
#  20  Leduc Community Hospital            9138 non-null   float64
#  21  Northeast Community Health Centre   9139 non-null   float64
#  22  Stollery Children's Hospital        9138 non-null   float64
#  23  Sturgeon Community Hospital         9138 non-null   float64
#  24  WestView Health Centre              9138 non-null   float64
#  25  Chinook Regional Hospital           8822 non-null   float64
#  26  Medicine Hat Regional Hospital      8816 non-null   float64
#  27  Red Deer Regional Hospital          9113 non-null   float64
#  28  Lacombe Hospital and Care Centre    0 non-null      float64
#  29  Innisfail Health Centre             0 non-null      float64
# dtypes: float64(27), int64(1), object(2)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Make 'datetime' column from 'Date', 'Year', 'Time' columns in raw dataset

# %%
df = raw.copy()
Utility.make_datetime_column_on_raw_waittime_df(df)
#df.insert(df.columns.get_loc('Time') + 1, 'datetime', pd.to_datetime(df['Year'].astype(str) + ' ' + df['Date'] + ' ' + df['Time'], format='%Y %d-%b %I:%M %p'))

# %%
df.head()
# Out:
#      Date  Year     Time            datetime  Alberta Children's Hospital  \
# 0  24-Sep  2022  6:22 PM 2022-09-24 18:22:00                        201.0
# 1  24-Sep  2022  6:23 PM 2022-09-24 18:23:00                        201.0
# 2  24-Sep  2022  8:25 PM 2022-09-24 20:25:00                        236.0
# 3  24-Sep  2022  8:27 PM 2022-09-24 20:27:00                        236.0
# 4  24-Sep  2022  8:28 PM 2022-09-24 20:28:00                        237.0
#
#    Foothills Medical Centre  Peter Lougheed Centre  \
# 0                     188.0                  116.0
# 1                     188.0                  116.0
# 2                     140.0                  124.0
# 3                     140.0                  124.0
# 4                     140.0                  124.0
#
#    Rockyview General Hospital  South Health Campus  Sheldon M. Chumir Centre  \
# 0                       148.0                154.0                      89.0
# 1                       148.0                154.0                      89.0
# 2                       120.0                150.0                      58.0
# 3                       120.0                150.0                      58.0
# 4                       106.0                151.0                      58.0
#
#    South Calgary Health Centre  Airdrie Community Health Centre  \
# 0                        193.0                              NaN
# 1                        193.0                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
#
#    Cochrane Community Health Centre  Okotoks Health and Wellness Centre  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    Devon General Hospital  Grey Nuns Community Hospital  \
# 0                   132.0                         147.0
# 1                   132.0                         147.0
# 2                   158.0                         224.0
# 3                   158.0                         224.0
# 4                   158.0                         216.0
#
#    Misericordia Community Hospital  Royal Alexandra Hospital  \
# 0                            384.0                     287.0
# 1                            384.0                     287.0
# 2                            285.0                     415.0
# 3                            285.0                     415.0
# 4                            281.0                     415.0
#
#    Strathcona Community Hospital  University of Alberta Hospital  \
# 0                          196.0                           234.0
# 1                          196.0                           234.0
# 2                          251.0                           301.0
# 3                          251.0                           301.0
# 4                          251.0                           301.0
#
#    Fort Sask Community Hospital  Leduc Community Hospital  \
# 0                         295.0                     293.0
# 1                         295.0                     293.0
# 2                         188.0                     158.0
# 3                         188.0                     158.0
# 4                         188.0                     158.0
#
#    Northeast Community Health Centre  Stollery Children's Hospital  \
# 0                              135.0                         199.0
# 1                              135.0                         199.0
# 2                              283.0                         179.0
# 3                              283.0                         179.0
# 4                              283.0                         179.0
#
#    Sturgeon Community Hospital  WestView Health Centre  \
# 0                        261.0                   189.0
# 1                        261.0                   189.0
# 2                        203.0                   351.0
# 3                        203.0                   351.0
# 4                        203.0                   351.0
#
#    Chinook Regional Hospital  Medicine Hat Regional Hospital  \
# 0                       69.0                            96.0
# 1                       69.0                            96.0
# 2                       79.0                            60.0
# 3                       79.0                            60.0
# 4                       73.0                            60.0
#
#    Red Deer Regional Hospital  Lacombe Hospital and Care Centre  \
# 0                       161.0                               NaN
# 1                       161.0                               NaN
# 2                       241.0                               NaN
# 3                       241.0                               NaN
# 4                       230.0                               NaN
#
#    Innisfail Health Centre
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9186 entries, 0 to 9185
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                9186 non-null   object
#  1   Year                                9186 non-null   int64
#  2   Time                                9186 non-null   object
#  3   datetime                            9186 non-null   datetime64[ns]
#  4   Alberta Children's Hospital         9111 non-null   float64
#  5   Foothills Medical Centre            9093 non-null   float64
#  6   Peter Lougheed Centre               9103 non-null   float64
#  7   Rockyview General Hospital          9108 non-null   float64
#  8   South Health Campus                 9108 non-null   float64
#  9   Sheldon M. Chumir Centre            9111 non-null   float64
#  10  South Calgary Health Centre         4556 non-null   float64
#  11  Airdrie Community Health Centre     5153 non-null   float64
#  12  Cochrane Community Health Centre    405 non-null    float64
#  13  Okotoks Health and Wellness Centre  0 non-null      float64
#  14  Devon General Hospital              9139 non-null   float64
#  15  Grey Nuns Community Hospital        9138 non-null   float64
#  16  Misericordia Community Hospital     9131 non-null   float64
#  17  Royal Alexandra Hospital            9138 non-null   float64
#  18  Strathcona Community Hospital       9139 non-null   float64
#  19  University of Alberta Hospital      9138 non-null   float64
#  20  Fort Sask Community Hospital        9138 non-null   float64
#  21  Leduc Community Hospital            9138 non-null   float64
#  22  Northeast Community Health Centre   9139 non-null   float64
#  23  Stollery Children's Hospital        9138 non-null   float64
#  24  Sturgeon Community Hospital         9138 non-null   float64
#  25  WestView Health Centre              9138 non-null   float64
#  26  Chinook Regional Hospital           8822 non-null   float64
#  27  Medicine Hat Regional Hospital      8816 non-null   float64
#  28  Red Deer Regional Hospital          9113 non-null   float64
#  29  Lacombe Hospital and Care Centre    0 non-null      float64
#  30  Innisfail Health Centre             0 non-null      float64
# dtypes: datetime64[ns](1), float64(27), int64(1), object(2)
# memory usage: 2.2+ MB

# %% [markdown]
# Descriptive Statistics on original (numeric) data (minus 'Year')

# %%
# Show descriptive statistics for all numerical columns except 'Year'
df.drop(['Year'], axis=1).describe()
# Out:
#                             datetime  Alberta Children's Hospital  \
# count                           9186                  9111.000000
# mean   2023-04-24 07:19:15.558458880                   199.572385
# min              2022-09-24 18:22:00                    30.000000
# 25%              2023-01-11 02:16:00                   115.000000
# 50%              2023-04-17 00:31:00                   170.000000
# 75%              2023-08-18 19:46:00                   247.000000
# max              2023-11-22 14:01:00                  1036.000000
# std                              NaN                   129.254659
#
#        Foothills Medical Centre  Peter Lougheed Centre  \
# count               9093.000000            9103.000000
# mean                 247.315188             295.444908
# min                   30.000000              30.000000
# 25%                  182.000000             182.000000
# 50%                  235.000000             263.000000
# 75%                  297.000000             373.000000
# max                  775.000000            1175.000000
# std                   94.868087             158.920631
#
#        Rockyview General Hospital  South Health Campus  \
# count                 9108.000000          9108.000000
# mean                   223.920290           281.944664
# min                     30.000000            30.000000
# 25%                    148.000000           189.000000
# 50%                    198.000000           250.000000
# 75%                    269.000000           341.000000
# max                    827.000000           962.000000
# std                    110.241707           136.238886
#
#        Sheldon M. Chumir Centre  South Calgary Health Centre  \
# count               9111.000000                  4556.000000
# mean                 214.177917                   128.221686
# min                   30.000000                    30.000000
# 25%                  126.000000                    92.000000
# 50%                  181.000000                   126.000000
# 75%                  273.000000                   165.000000
# max                  873.000000                   356.000000
# std                  124.172176                    53.689182
#
#        Airdrie Community Health Centre  Cochrane Community Health Centre  \
# count                      5153.000000                        405.000000
# mean                        154.160295                         98.664198
# min                          30.000000                         30.000000
# 25%                          95.000000                         45.000000
# 50%                         141.000000                         90.000000
# 75%                         198.000000                        135.000000
# max                         595.000000                        417.000000
# std                          84.232355                         62.620465
#
#        Okotoks Health and Wellness Centre  Devon General Hospital  \
# count                                 0.0             9139.000000
# mean                                  NaN              137.568881
# min                                   NaN               30.000000
# 25%                                   NaN               55.000000
# 50%                                   NaN              123.000000
# 75%                                   NaN              201.000000
# max                                   NaN              663.000000
# std                                   NaN               90.998597
#
#        Grey Nuns Community Hospital  Misericordia Community Hospital  \
# count                   9138.000000                      9131.000000
# mean                     180.614467                       289.894316
# min                       30.000000                        30.000000
# 25%                      129.000000                       208.000000
# 50%                      173.000000                       277.000000
# 75%                      222.000000                       357.500000
# max                      600.000000                       873.000000
# std                       79.754128                       116.844342
#
#        Royal Alexandra Hospital  Strathcona Community Hospital  \
# count               9138.000000                    9139.000000
# mean                 273.938499                     174.418536
# min                   30.000000                      30.000000
# 25%                  206.000000                     107.000000
# 50%                  268.000000                     170.000000
# 75%                  336.000000                     230.000000
# max                  623.000000                     667.000000
# std                   96.761785                      91.012240
#
#        University of Alberta Hospital  Fort Sask Community Hospital  \
# count                     9138.000000                   9138.000000
# mean                       270.942766                    175.356095
# min                         30.000000                     30.000000
# 25%                        194.000000                     87.000000
# 50%                        265.000000                    160.000000
# 75%                        340.000000                    250.000000
# max                        732.000000                    863.000000
# std                        103.040386                    114.524353
#
#        Leduc Community Hospital  Northeast Community Health Centre  \
# count               9138.000000                        9139.000000
# mean                 151.941125                         209.492395
# min                   30.000000                          30.000000
# 25%                   79.000000                         140.000000
# 50%                  140.000000                         197.000000
# 75%                  212.000000                         261.000000
# max                  548.000000                         916.000000
# std                   91.975606                         100.464304
#
#        Stollery Children's Hospital  Sturgeon Community Hospital  \
# count                   9138.000000                  9138.000000
# mean                     193.127708                   202.523309
# min                       30.000000                    30.000000
# 25%                      118.000000                   132.250000
# 50%                      179.000000                   196.000000
# 75%                      246.000000                   266.000000
# max                      988.000000                   723.000000
# std                      109.721164                    97.699090
#
#        WestView Health Centre  Chinook Regional Hospital  \
# count             9138.000000                8822.000000
# mean               181.231889                 102.804126
# min                 30.000000                  30.000000
# 25%                108.000000                  52.000000
# 50%                174.000000                  89.000000
# 75%                243.000000                 136.000000
# max                658.000000                 593.000000
# std                 97.816309                  65.807900
#
#        Medicine Hat Regional Hospital  Red Deer Regional Hospital  \
# count                     8816.000000                 9113.000000
# mean                        92.503063                  258.548776
# min                         30.000000                   30.000000
# 25%                         42.000000                  162.000000
# 50%                         81.000000                  235.000000
# 75%                        126.250000                  331.000000
# max                        443.000000                 1069.000000
# std                         59.517961                  136.640915
#
#        Lacombe Hospital and Care Centre  Innisfail Health Centre
# count                               0.0                      0.0
# mean                                NaN                      NaN
# min                                 NaN                      NaN
# 25%                                 NaN                      NaN
# 50%                                 NaN                      NaN
# 75%                                 NaN                      NaN
# max                                 NaN                      NaN
# std                                 NaN                      NaN

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Time', 'datetime', 'Alberta Children's Hospital',
#        'Foothills Medical Centre', 'Peter Lougheed Centre',
#        'Rockyview General Hospital', 'South Health Campus',
#        'Sheldon M. Chumir Centre', 'South Calgary Health Centre',
#        'Airdrie Community Health Centre', 'Cochrane Community Health Centre',
#        'Okotoks Health and Wellness Centre', 'Devon General Hospital',
#        'Grey Nuns Community Hospital', 'Misericordia Community Hospital',
#        'Royal Alexandra Hospital', 'Strathcona Community Hospital',
#        'University of Alberta Hospital', 'Fort Sask Community Hospital',
#        'Leduc Community Hospital', 'Northeast Community Health Centre',
#        'Stollery Children's Hospital', 'Sturgeon Community Hospital',
#        'WestView Health Centre', 'Chinook Regional Hospital',
#        'Medicine Hat Regional Hospital', 'Red Deer Regional Hospital',
#        'Lacombe Hospital and Care Centre', 'Innisfail Health Centre'],
#       dtype='object')

# %% [markdown]
# Define function that princes stats about number of nulls for each column in a dataframe

# %%
# Use Utility function to print Null statistics for dataframe
Utility.print_num_stats(df)
# Out:
# Stats for Number of Nulls:
#
# Column Name                             :      Null Percentage     Num Nulls      Num Rows
# -----------                             :      ---------------     ---------      --------
# Date                                    :                 0.00%            0         9186
# Year                                    :                 0.00%            0         9186
# Time                                    :                 0.00%            0         9186
# datetime                                :                 0.00%            0         9186
# Alberta Children's Hospital             :                 0.82%           75         9186
# Foothills Medical Centre                :                 1.01%           93         9186
# Peter Lougheed Centre                   :                 0.90%           83         9186
# Rockyview General Hospital              :                 0.85%           78         9186
# South Health Campus                     :                 0.85%           78         9186
# Sheldon M. Chumir Centre                :                 0.82%           75         9186
# South Calgary Health Centre             :                50.40%         4630         9186
# Airdrie Community Health Centre         :                43.90%         4033         9186
# Cochrane Community Health Centre        :                95.59%         8781         9186
# Okotoks Health and Wellness Centre      :               100.00%         9186         9186
# Devon General Hospital                  :                 0.51%           47         9186
# Grey Nuns Community Hospital            :                 0.52%           48         9186
# Misericordia Community Hospital         :                 0.60%           55         9186
# Royal Alexandra Hospital                :                 0.52%           48         9186
# Strathcona Community Hospital           :                 0.51%           47         9186
# University of Alberta Hospital          :                 0.52%           48         9186
# Fort Sask Community Hospital            :                 0.52%           48         9186
# Leduc Community Hospital                :                 0.52%           48         9186
# Northeast Community Health Centre       :                 0.51%           47         9186
# Stollery Children's Hospital            :                 0.52%           48         9186
# Sturgeon Community Hospital             :                 0.52%           48         9186
# WestView Health Centre                  :                 0.52%           48         9186
# Chinook Regional Hospital               :                 3.96%          364         9186
# Medicine Hat Regional Hospital          :                 4.03%          370         9186
# Red Deer Regional Hospital              :                 0.79%           73         9186
# Lacombe Hospital and Care Centre        :               100.00%         9186         9186
# Innisfail Health Centre                 :               100.00%         9186         9186

# %% [markdown]
# Drop columns corresponding to hospitals that have 100% null data

# %%
# Since Okotoks, Lacombe and Innisfail have 100% nulls, drop these columns altogether.
df.drop(columns=['Okotoks Health and Wellness Centre', 'Lacombe Hospital and Care Centre', 'Innisfail Health Centre'], axis=1, inplace=True)

# %% [markdown]
# # Create `df_melted`
# * Melt (reverse-pivot) the dataset so the columns are: Datetime, Hospital, Wait Time
# * New dataframe will be called df_melted

# %%
# Melt the DF (reverse pivot) to put the Hospital Names into a single column
desired_columns = (df.columns[~df.columns.isin(['Date', 'Time', 'Year'])]).tolist()
df_melted = pd.melt(df[desired_columns], id_vars=['datetime'], var_name='hospital', value_name='waittime')

# %%
df_melted.head(15)
# Out:
#               datetime                     hospital  waittime
# 0  2022-09-24 18:22:00  Alberta Children's Hospital     201.0
# 1  2022-09-24 18:23:00  Alberta Children's Hospital     201.0
# 2  2022-09-24 20:25:00  Alberta Children's Hospital     236.0
# 3  2022-09-24 20:27:00  Alberta Children's Hospital     236.0
# 4  2022-09-24 20:28:00  Alberta Children's Hospital     237.0
# 5  2022-09-24 20:29:00  Alberta Children's Hospital     239.0
# 6  2022-09-24 20:30:00  Alberta Children's Hospital     239.0
# 7  2022-09-24 20:31:00  Alberta Children's Hospital     239.0
# 8  2022-09-24 20:32:00  Alberta Children's Hospital     241.0
# 9  2022-09-24 20:33:00  Alberta Children's Hospital     241.0
# 10 2022-09-24 21:01:00  Alberta Children's Hospital     288.0
# 11 2022-09-24 22:01:00  Alberta Children's Hospital     314.0
# 12 2022-09-24 23:01:00  Alberta Children's Hospital     448.0
# 13 2022-09-25 00:01:00  Alberta Children's Hospital     423.0
# 14 2022-09-25 01:01:00  Alberta Children's Hospital     436.0

# %% [markdown]
# On new `df_melted` dataframe: Sort ascending by datetime and reset index

# %%
# Sort the df_melted dataframe ascending by Datetime and Hospital

df_melted.sort_values(by=['datetime', 'hospital'], ascending=[True, True], inplace=True)
df_melted.reset_index(drop=True, inplace=True)

# %%
df_melted.head()
# Out:
#              datetime                          hospital  waittime
# 0 2022-09-24 18:22:00   Airdrie Community Health Centre       NaN
# 1 2022-09-24 18:22:00       Alberta Children's Hospital     201.0
# 2 2022-09-24 18:22:00         Chinook Regional Hospital      69.0
# 3 2022-09-24 18:22:00  Cochrane Community Health Centre       NaN
# 4 2022-09-24 18:22:00            Devon General Hospital     132.0

# %%
df_melted.shape
# Out:
# (220464, 3)

# %%
Utility.print_num_stats(df_melted)
# Out:
# Stats for Number of Nulls:
#
# Column Name                             :      Null Percentage     Num Nulls      Num Rows
# -----------                             :      ---------------     ---------      --------
# datetime                                :                 0.00%            0       220464
# hospital                                :                 0.00%            0       220464
# waittime                                :                 8.76%        19313       220464

# %% [markdown]
# Prepare to drop remaining null rows corresponding to datetime values where there was no waittime information for a given hospital

# %%
# Show how many rows of data, per hospital per date, will be dropped when I dropna() on this dataframe in the next cell.
# Credit to GitHub Copilot for the below code:
df_nulls = df_melted[df_melted['waittime'].isnull()][['hospital', 'datetime']].value_counts().reset_index()
df_nulls.columns = ['hospital', 'datetime', 'Count of Nulls to be Dropped']
df_nulls['datetime'] = df_nulls['datetime'].dt.date
df_nulls = df_nulls.drop_duplicates(subset=['hospital', 'datetime'], keep='first')
df_nulls.head(50)
# Out:
#                              hospital    datetime  \
# 0            Sheldon M. Chumir Centre  2022-11-06
# 1          Red Deer Regional Hospital  2023-11-05
# 2         South Calgary Health Centre  2023-11-05
# 3         South Calgary Health Centre  2022-11-06
# 4     Airdrie Community Health Centre  2022-11-06
# 5           Chinook Regional Hospital  2023-11-05
# 6           Chinook Regional Hospital  2022-11-06
# 7    Cochrane Community Health Centre  2023-11-05
# 8    Cochrane Community Health Centre  2022-11-06
# 9      Medicine Hat Regional Hospital  2022-11-06
# 10        Alberta Children's Hospital  2022-11-06
# 11           Foothills Medical Centre  2022-11-06
# 12     Medicine Hat Regional Hospital  2023-11-05
# 13              Peter Lougheed Centre  2022-11-06
# 14         Red Deer Regional Hospital  2022-11-06
# 15                South Health Campus  2022-11-06
# 16         Rockyview General Hospital  2022-11-06
# 17   Cochrane Community Health Centre  2023-10-19
# 18   Cochrane Community Health Centre  2023-10-20
# 20   Cochrane Community Health Centre  2023-10-18
# 33   Cochrane Community Health Centre  2023-10-21
# 82    Airdrie Community Health Centre  2022-09-24
# 85   Cochrane Community Health Centre  2023-10-23
# 104  Cochrane Community Health Centre  2023-10-24
# 105  Cochrane Community Health Centre  2023-10-25
# 123  Cochrane Community Health Centre  2023-10-22
# 159  Cochrane Community Health Centre  2023-10-14
# 179  Cochrane Community Health Centre  2023-10-15
# 197  Cochrane Community Health Centre  2023-10-13
# 201  Cochrane Community Health Centre  2023-10-12
# 235  Cochrane Community Health Centre  2023-10-17
# 273  Cochrane Community Health Centre  2023-10-16
# 311  Cochrane Community Health Centre  2023-11-15
# 312  Cochrane Community Health Centre  2023-11-14
# 323  Cochrane Community Health Centre  2023-11-13
# 331  Cochrane Community Health Centre  2023-11-16
# 349  Cochrane Community Health Centre  2023-11-11
# 355  Cochrane Community Health Centre  2023-11-10
# 364  Cochrane Community Health Centre  2023-11-09
# 371  Cochrane Community Health Centre  2023-11-12
# 385  Cochrane Community Health Centre  2023-11-17
# 387  Cochrane Community Health Centre  2023-11-22
# 393  Cochrane Community Health Centre  2023-11-21
# 405  Cochrane Community Health Centre  2023-11-20
# 407            Devon General Hospital  2023-01-24
# 409            Devon General Hospital  2023-01-23
# 421            Devon General Hospital  2022-11-06
# 425  Cochrane Community Health Centre  2023-11-18
# 444  Cochrane Community Health Centre  2023-11-19
# 463  Cochrane Community Health Centre  2023-10-31
#
#      Count of Nulls to be Dropped
# 0                               2
# 1                               2
# 2                               2
# 3                               2
# 4                               2
# 5                               2
# 6                               2
# 7                               2
# 8                               2
# 9                               2
# 10                              2
# 11                              2
# 12                              2
# 13                              2
# 14                              2
# 15                              2
# 16                              2
# 17                              1
# 18                              1
# 20                              1
# 33                              1
# 82                              1
# 85                              1
# 104                             1
# 105                             1
# 123                             1
# 159                             1
# 179                             1
# 197                             1
# 201                             1
# 235                             1
# 273                             1
# 311                             1
# 312                             1
# 323                             1
# 331                             1
# 349                             1
# 355                             1
# 364                             1
# 371                             1
# 385                             1
# 387                             1
# 393                             1
# 405                             1
# 407                             1
# 409                             1
# 421                             1
# 425                             1
# 444                             1
# 463                             1

# %% [markdown]
# # Create new dataframe `df_clean` which calls dropna() on `df_melted`:
# * to drop all datetime entries per hospital, with null waittime
# * Note: We cannot easily (nor do we want to) impute these nulls, so will just drop them.

# %%
# Drop all rows with null WaitTimes
df_clean = df_melted.dropna().reset_index(drop=True)

# %%
df_clean.head()
# Out:
#              datetime                      hospital  waittime
# 0 2022-09-24 18:22:00   Alberta Children's Hospital     201.0
# 1 2022-09-24 18:22:00     Chinook Regional Hospital      69.0
# 2 2022-09-24 18:22:00        Devon General Hospital     132.0
# 3 2022-09-24 18:22:00      Foothills Medical Centre     188.0
# 4 2022-09-24 18:22:00  Fort Sask Community Hospital     295.0

# %%
df_clean.shape
# Out:
# (201151, 3)

# %%
# Check our numbers - that nothing was dropped that shouldn't have been.  Expecting a "True" from the assert below:
df_melted.shape[0] - df_clean.shape[0] == df_melted[df_melted['waittime'].isnull()].shape[0]
# Out:
# True

# %% [markdown]
# # Feature Engineering on `df_clean`
# Add the following columns:
# * Year
# * Day of Week
# * Week of Year - is the isocalendar week (starting on Monday, ending on Sunday)
# * Month of Year
# * Hour
# * Day Period:  Per an ER Clinician-Researcher, use the following:
#     - 'day': 08h00-15h59
#     - 'evening': 16h00-2359 evening
#     - 'night': 24h00-7h59
# * City
# * Services: (from Hospitals Info df)
#     - 'emergency': Offers 24x7 emergency care per AHS website on the hospital
#     -  'urgentcare': Does not have an ER per per AHS website on the hospital
# * City Status (from Hospitals Info df)
#     - 'urban': Urban (if city population >= 600,000)
#     - 'peri': Peri-Urban (if city population >= 30,000 and < 600,000)
#     - 'rural': Rural setting (if city population < 30,000)

# %%
# Add the features for Year, Day of Week, Week of Year, Hour, Day Period

df_clean['year'] = df_clean['datetime'].dt.year
df_clean['dayofweek'] = df_clean['datetime'].dt.day_name()
df_clean['numdayofweek'] = df_clean['datetime'].dt.dayofweek # May later want a number 0-6, 0 = Monday, 6 = Sunday
df_clean['weekofyear'] = df_clean['datetime'].dt.isocalendar().week
df_clean['hour'] = df_clean['datetime'].dt.hour

# Create 'dayperiod' feature using definitions of bins and labels from Utility class
Utility.add_dayperiod_feature(df_clean)

# %%
df_clean.columns
# Out:
# Index(['datetime', 'hospital', 'waittime', 'year', 'dayofweek', 'numdayofweek',
#        'weekofyear', 'hour', 'dayperiod'],
#       dtype='object')

# %%
# Remind ourselves about the hospital info dataframe which we'll merged into df_clean
info.head()
# Out:
#                           name   id   services     city province  city.area  \
# 0  Alberta Children's Hospital  ach  emergency  Calgary  Alberta        826
# 1     Foothills Medical Centre  fmc  emergency  Calgary  Alberta        826
# 2        Peter Lougheed Centre  plc  emergency  Calgary  Alberta        826
# 3   Rockyview General Hospital  rgh  emergency  Calgary  Alberta        826
# 4          South Health Campus  shc  emergency  Calgary  Alberta        826
#
#    city.lat  city.long   city.pop citytype  \
# 0     51.05  -114.0667  1,306,784    urban
# 1     51.05  -114.0667  1,306,784    urban
# 2     51.05  -114.0667  1,306,784    urban
# 3     51.05  -114.0667  1,306,784    urban
# 4     51.05  -114.0667  1,306,784    urban
#
#                                            address   hosp_lat   hosp_long
# 0       28 Oki Drive NW, Calgary, Alberta, T3B 6A8  51.074759 -114.146833
# 1     1403 29 Street NW, Calgary, Alberta, T2N 2T9  51.064657 -114.130926
# 2     3500 26 Avenue NE, Calgary, Alberta, T1Y 6J4  51.078914 -113.984611
# 3     7007 14 Street SW, Calgary, Alberta, T2V 1P9  50.990056 -114.097077
# 4  4448 Front Street SE, Calgary, Alberta, T3M 1M4  50.880825 -113.952720

# %%
info['id'].tolist()
# Out:
# ['ach',
#  'fmc',
#  'plc',
#  'rgh',
#  'shc',
#  'smcc',
#  'schc',
#  'achc',
#  'cchc',
#  'ohwc',
#  'dgh',
#  'gnch',
#  'mch',
#  'rah',
#  'schc',
#  'uah',
#  'fsch',
#  'lch',
#  'nchc',
#  'stollery',
#  'sch',
#  'whc',
#  'crh',
#  'mhrh',
#  'rdrh',
#  'lhcc',
#  'ihc']

# %% [markdown]
# # Create `df_merged` dataframe:
# * is `df_clean` plus city, city.area, city.pop, citytype, hospital id, hosp_lat, hosp_long features from the Hospital info (info) dataframe

# %%
# Add the City, Services, and CityStatus features from the hosptial_info_clean.csv file (info df)
df_merged = pd.merge(df_clean, info[['id', 'services', 'city', 'city.area', 'city.pop', 'citytype', 'hosp_lat', 'hosp_long', 'name']], how='left', left_on='hospital', right_on='name')
df_merged.drop(columns=['name'], axis=1, inplace=True)

# %%
df_merged.head(2)
# Out:
#              datetime                     hospital  waittime  year dayofweek  \
# 0 2022-09-24 18:22:00  Alberta Children's Hospital     201.0  2022  Saturday
# 1 2022-09-24 18:22:00    Chinook Regional Hospital      69.0  2022  Saturday
#
#    numdayofweek  weekofyear  hour dayperiod   id   services        city  \
# 0             5          38    18   evening  ach  emergency     Calgary
# 1             5          38    18   evening  crh  emergency  Lethbridge
#
#    city.area   city.pop citytype   hosp_lat   hosp_long
# 0        826  1,306,784    urban  51.074759 -114.146833
# 1        122     98,406     peri  49.685221 -112.816209

# %%
df_merged.rename(columns={
    'city.area': 'cityarea',
    'city.pop': 'citypop',
    'hosp_lat': 'hosplat',
    'hosp_long': 'hosplong'
    },
    inplace=True)

# %%
df_merged.head(2)
# Out:
#              datetime                     hospital  waittime  year dayofweek  \
# 0 2022-09-24 18:22:00  Alberta Children's Hospital     201.0  2022  Saturday
# 1 2022-09-24 18:22:00    Chinook Regional Hospital      69.0  2022  Saturday
#
#    numdayofweek  weekofyear  hour dayperiod   id   services        city  \
# 0             5          38    18   evening  ach  emergency     Calgary
# 1             5          38    18   evening  crh  emergency  Lethbridge
#
#    cityarea    citypop citytype    hosplat    hosplong
# 0       826  1,306,784    urban  51.074759 -114.146833
# 1       122     98,406     peri  49.685221 -112.816209

# %% [markdown]
# Statistics of row counts (number of waittime observations) for each hospital after the null rows were dropped

# %%
# Get the counts for each hospital
df_merged.groupby(['city', 'hospital']).size().sort_index(level=[0, 1], sort_remaining=False).sort_values(ascending=True)
# Out:
# city               hospital
# Cochrane           Cochrane Community Health Centre      405
# Calgary            South Calgary Health Centre          4556
# Airdrie            Airdrie Community Health Centre      5153
# Medicine Hat       Medicine Hat Regional Hospital       8816
# Lethbridge         Chinook Regional Hospital            8822
# Calgary            Foothills Medical Centre             9093
#                    Peter Lougheed Centre                9103
#                    Rockyview General Hospital           9108
#                    South Health Campus                  9108
#                    Alberta Children's Hospital          9111
#                    Sheldon M. Chumir Centre             9111
# Red Deer           Red Deer Regional Hospital           9113
# Edmonton           Misericordia Community Hospital      9131
#                    Royal Alexandra Hospital             9138
#                    Stollery Children's Hospital         9138
#                    University of Alberta Hospital       9138
# Fort Saskatchewan  Fort Sask Community Hospital         9138
# Leduc              Leduc Community Hospital             9138
# St. Albert         Sturgeon Community Hospital          9138
# Edmonton           Grey Nuns Community Hospital         9138
# Stony Plain        WestView Health Centre               9138
# Devon              Devon General Hospital               9139
# Sherwood Park      Strathcona Community Hospital        9139
# Edmonton           Northeast Community Health Centre    9139
# dtype: int64

# %% [markdown]
# Check datatypes to ensure all numerical data is cast as integers

# %%
df_merged.dtypes
# Out:
# datetime        datetime64[ns]
# hospital                object
# waittime               float64
# year                     int32
# dayofweek               object
# numdayofweek             int32
# weekofyear              UInt32
# hour                     int32
# dayperiod             category
# id                      object
# services                object
# city                    object
# cityarea                 int64
# citypop                 object
# citytype                object
# hosplat                float64
# hosplong               float64
# dtype: object

# %%
# Fix datatype of citypop to make it a number
df_merged['citypop'] = df_merged['citypop'].str.replace(',', '').astype('int64')

# %%
df_merged.head(5)
# Out:
#              datetime                      hospital  waittime  year dayofweek  \
# 0 2022-09-24 18:22:00   Alberta Children's Hospital     201.0  2022  Saturday
# 1 2022-09-24 18:22:00     Chinook Regional Hospital      69.0  2022  Saturday
# 2 2022-09-24 18:22:00        Devon General Hospital     132.0  2022  Saturday
# 3 2022-09-24 18:22:00      Foothills Medical Centre     188.0  2022  Saturday
# 4 2022-09-24 18:22:00  Fort Sask Community Hospital     295.0  2022  Saturday
#
#    numdayofweek  weekofyear  hour dayperiod    id   services  \
# 0             5          38    18   evening   ach  emergency
# 1             5          38    18   evening   crh  emergency
# 2             5          38    18   evening   dgh  emergency
# 3             5          38    18   evening   fmc  emergency
# 4             5          38    18   evening  fsch  emergency
#
#                 city  cityarea  citypop citytype    hosplat    hosplong
# 0            Calgary       826  1306784    urban  51.074759 -114.146833
# 1         Lethbridge       122    98406     peri  49.685221 -112.816209
# 2              Devon        14     6545    rural  53.352265 -113.728288
# 3            Calgary       826  1306784    urban  51.064657 -114.130926
# 4  Fort Saskatchewan        48    27088    rural  53.693175 -113.213436

# %% [markdown]
# # Write dataframes out to disk under the cleandata subdirectory:
#
#  | Name of df in this   notebook | Description of What DataFrame   Contains                                                                                                                                                                                                                                                                                                                                                 | Path on Disk                         | Filename                               |
# |-------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------|----------------------------------------|
# | `info`                        | Dataframe with hospital   information, to be merged with wait time dataframe.                                                                                                                                                                                                                                                                                                            | <project_root>/data/cleandata/ | hospital_info_clean.csv                |
# | `df`                          | Dataframe with raw data   originally from CBC screenscrape plus extra 'datetime' column, created from   Day, Year, and Time columns from original dataset.  3 Hospital columns entirely of null values   dropped (Okotoks, Lacombe, Innisfail).                                                                                                                                          | <project_root>/data/cleandata/ | df_er_wait_time_nov_22_2023.csv        |
# | `df_melted`                   | `df` dataframe with raw data and   datetime column minus 3 null value hospitals melted to be 3 columns:  'datetime', 'hospital', 'waittime'                                                                                                                                                                                                                                              | <project_root>/data/cleandata/ | df_melted_er_wait_time_nov_22_2023.csv |
# | `df_clean`                    | `df_melted` dataframe with   'datetime', 'hospital', 'waittime', with null rows dropped and the following   features engineered: 'year', 'dayofweek', 'numdayofweek' (0 = Monday, 6 =   Sunday), 'weekofyear' (isocalendar with Monday start of week and Sunday end of   week), 'hour', 'dayperiod' ('night', 'day', 'evening')                                                          | <project_root>/data/cleandata/ | df_clean_er_wait_time_nov_22_2023.csv  |
# | `df_merged`                   | `df_clean` dataframe with   additional columns (hospital information) merged from `info` dataframe, as   follows: 'id' ('ach', 'crh', etc.), 'services' ('emergency', 'urgentcare'),   city, cityarea, citypop, citytype ('urban', 'peri', 'rural'), hosplat, hosplong.            FINAL DF to be loaded and used in subsequent notebooks for EDA, hypothesis   testing, model building. | <project_root>/data/cleandata/ | df_final_er_wait_time_nov_22_2023.csv  |

# %%
# Write the raw data originally from CBC, with datetime added, and 3 null columns/hospitals dropped, to a csv file for later use

#df.to_csv('cleandata/df_er_wait_time_nov_22_2023.csv', index=False)
df.to_csv(Utility.RAW_WAIT_DATETIME_DROP_NULL_HOSPITALS_DF_FILENAME, index=False)

# Write the melted dataframe: 'datetime', 'hospital', 'waittime', merged dataframe to a csv file for later use
#df_melted.to_csv('cleandata/df_melted_er_wait_time_nov_22_2023.csv', index=False)
df_melted.to_csv(Utility.RAW_WAIT_INITIAL_MELTED_DF_MELTED_FILENAME, index=False)

# Write the cleaned dataframe: melted, nulls dropped, datetime-type features engineered, to a csv file for later use
#df_clean.to_csv('cleandata/df_clean_er_wait_time_nov_22_2023.csv', index=False)
df_clean.to_csv(Utility.RAW_WAIT_DROPNULL_DATETIME_FEATURE_ENG_DF_CLEAN_FILENAME, index=False)

# Write the final df with: datetime/hospital/waittime columns, cleaned (no nulls), feature engineered, merged dataframe, to a csv file for later use
#df_merged.to_csv('cleandata/df_final_er_wait_time_nov_22_2023.csv', index=False)
df_merged.to_csv(Utility.CLEAN_WAIT_FILENAME, index=False)
